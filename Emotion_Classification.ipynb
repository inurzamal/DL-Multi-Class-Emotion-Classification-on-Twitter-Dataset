# %% [markdown]
# # Multiclass Emotion Classification using Deep Learning

# %%
import tensorflow as tf
from tensorflow import keras

import pandas as pd
# Out:
# C:\Users\nzama\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
df=pd.read_csv("emotion.csv")

df
# Out:
#                                                      text  emotions
# 0       i feel awful about it too because it s my job ...   sadness
# 1                                   im alone i feel awful   sadness
# 2       ive probably mentioned this before but i reall...       joy
# 3                i was feeling a little low few days back   sadness
# 4       i beleive that i am much more sensitive to oth...      love
# 5       i find myself frustrated with christians becau...      love
# 6       i am one of those people who feels like going ...       joy
# 7       i feel especially pleased about this as this h...       joy
# 8       i was struggling with these awful feelings and...       joy
# 9         i feel so enraged but helpless at the same time     anger
# 10                        i said feeling a bit rebellious     anger
# 11      i also feel disillusioned that someone who cla...   sadness
# 12      i mean is on this stupid trip of making the gr...       joy
# 13      i woke up feeling particularly vile tried to i...     anger
# 14      i could feel the vile moth burrowing its way i...     anger
# 15      i know its just doing its job and doesnt actua...       joy
# 16      i wish you knew every word i write i write for...   sadness
# 17      i feel weird knowing mine died when i wasn t a...      fear
# 18      i feel assured that there is no such thing as ...       joy
# 19      i feel blessed everyday for our little man and...      love
# 20      i feel exhausted when i go home but i am alway...   sadness
# 21      i stil can see kaibas face on every tv screen ...   sadness
# 22      i don t like to feel uncomfortable with being ...      fear
# 23           i was left kinda feeling stupid and insecure   sadness
# 24      i alternate between feeling sympathetic toward...      love
# 25      i have a pretty bad feeling the last two books...     anger
# 26      i sincerely believe that every client celebrit...       joy
# 27                    i don t feel comfortable around you       joy
# 28      i am happy that you don t feel as burdened and...   sadness
# 29      i am still here i am not dead yet but these th...   sadness
# ...                                                   ...       ...
# 416779      ive been feeling really lonely but thats good   sadness
# 416780  i want something that gives me a major orgasm ...      love
# 416781  i smile and thank them telling them im trainin...       joy
# 416782                                 i feel totes weird      fear
# 416783  i feel resentful thinking that some animal in ...     anger
# 416784  i want so badly to know what it feels like to ...       joy
# 416785      i feel like my writing is messy and scattered   sadness
# 416786  i can feel envious simply because shes wearing...     anger
# 416787  i didn t feel unwelcome at any point in fairba...   sadness
# 416788  ill admit there is definitely some sort of tes...     anger
# 416789        i feel when i want to be productive yet not       joy
# 416790                        i feel humiliated or stupid   sadness
# 416791  im tired and a little irrational and wearing t...      fear
# 416792  ive gone into races feeling pumped and confide...       joy
# 416793  i just feel very low of myself and i don t kno...   sadness
# 416794  i wasnt feeling brave enough to flash my bare ...       joy
# 416795  i had started to feel really complacent with m...       joy
# 416796  i really want to stop feeling caught between g...      love
# 416797  i feel even more strongly about what the colle...       joy
# 416798  im feeling generous today heres one more you m...      love
# 416799  i always feel so valued when i am with her bec...       joy
# 416800  im truly sorry for the abandoned feeling my fe...      love
# 416801  i do feel my body aching dying crying for slee...   sadness
# 416802  i can t imagine her having as much of an immed...  surprise
# 416803       i could never bear feeling a violent thought     anger
# 416804  that was what i felt when i was finally accept...       joy
# 416805  i take every day as it comes i m just focussin...      fear
# 416806      i just suddenly feel that everything was fake   sadness
# 416807  im feeling more eager than ever to claw back w...       joy
# 416808  i give you plenty of attention even when i fee...   sadness
#
# [416809 rows x 2 columns]

# %%
# shape indicates dimensions

df.shape # rows, columns = df.shape
# Out:
# (416809, 2)

# %%
df.head()
# Out:
#                                                 text emotions
# 0  i feel awful about it too because it s my job ...  sadness
# 1                              im alone i feel awful  sadness
# 2  ive probably mentioned this before but i reall...      joy
# 3           i was feeling a little low few days back  sadness
# 4  i beleive that i am much more sensitive to oth...     love

# %%
df.tail(10)
# Out:
#                                                      text  emotions
# 416799  i always feel so valued when i am with her bec...       joy
# 416800  im truly sorry for the abandoned feeling my fe...      love
# 416801  i do feel my body aching dying crying for slee...   sadness
# 416802  i can t imagine her having as much of an immed...  surprise
# 416803       i could never bear feeling a violent thought     anger
# 416804  that was what i felt when i was finally accept...       joy
# 416805  i take every day as it comes i m just focussin...      fear
# 416806      i just suddenly feel that everything was fake   sadness
# 416807  im feeling more eager than ever to claw back w...       joy
# 416808  i give you plenty of attention even when i fee...   sadness

# %%
# Let’s now take a look at the number of instances(rows) that belong to each class. We can view this as an absolute count.
df.groupby('emotions').size()
# Out:
# emotions
# anger        57317
# fear         47712
# joy         141067
# love         34554
# sadness     121187
# surprise     14972
# dtype: int64

# %%
#df = df[df.Sentiment != 'unsup']
df['emotions'] = df['emotions'].map({'anger': 0, 'fear': 1, 'joy': 2, 'love': 3, 'sadness': 4, 'surprise': 5})
df.head()
# Out:
#                                                 text  emotions
# 0  i feel awful about it too because it s my job ...         4
# 1                              im alone i feel awful         4
# 2  ive probably mentioned this before but i reall...         2
# 3           i was feeling a little low few days back         4
# 4  i beleive that i am much more sensitive to oth...         3

# %%
df
# Out:
#                                                      text  emotions
# 0       i feel awful about it too because it s my job ...         4
# 1                                   im alone i feel awful         4
# 2       ive probably mentioned this before but i reall...         2
# 3                i was feeling a little low few days back         4
# 4       i beleive that i am much more sensitive to oth...         3
# 5       i find myself frustrated with christians becau...         3
# 6       i am one of those people who feels like going ...         2
# 7       i feel especially pleased about this as this h...         2
# 8       i was struggling with these awful feelings and...         2
# 9         i feel so enraged but helpless at the same time         0
# 10                        i said feeling a bit rebellious         0
# 11      i also feel disillusioned that someone who cla...         4
# 12      i mean is on this stupid trip of making the gr...         2
# 13      i woke up feeling particularly vile tried to i...         0
# 14      i could feel the vile moth burrowing its way i...         0
# 15      i know its just doing its job and doesnt actua...         2
# 16      i wish you knew every word i write i write for...         4
# 17      i feel weird knowing mine died when i wasn t a...         1
# 18      i feel assured that there is no such thing as ...         2
# 19      i feel blessed everyday for our little man and...         3
# 20      i feel exhausted when i go home but i am alway...         4
# 21      i stil can see kaibas face on every tv screen ...         4
# 22      i don t like to feel uncomfortable with being ...         1
# 23           i was left kinda feeling stupid and insecure         4
# 24      i alternate between feeling sympathetic toward...         3
# 25      i have a pretty bad feeling the last two books...         0
# 26      i sincerely believe that every client celebrit...         2
# 27                    i don t feel comfortable around you         2
# 28      i am happy that you don t feel as burdened and...         4
# 29      i am still here i am not dead yet but these th...         4
# ...                                                   ...       ...
# 416779      ive been feeling really lonely but thats good         4
# 416780  i want something that gives me a major orgasm ...         3
# 416781  i smile and thank them telling them im trainin...         2
# 416782                                 i feel totes weird         1
# 416783  i feel resentful thinking that some animal in ...         0
# 416784  i want so badly to know what it feels like to ...         2
# 416785      i feel like my writing is messy and scattered         4
# 416786  i can feel envious simply because shes wearing...         0
# 416787  i didn t feel unwelcome at any point in fairba...         4
# 416788  ill admit there is definitely some sort of tes...         0
# 416789        i feel when i want to be productive yet not         2
# 416790                        i feel humiliated or stupid         4
# 416791  im tired and a little irrational and wearing t...         1
# 416792  ive gone into races feeling pumped and confide...         2
# 416793  i just feel very low of myself and i don t kno...         4
# 416794  i wasnt feeling brave enough to flash my bare ...         2
# 416795  i had started to feel really complacent with m...         2
# 416796  i really want to stop feeling caught between g...         3
# 416797  i feel even more strongly about what the colle...         2
# 416798  im feeling generous today heres one more you m...         3
# 416799  i always feel so valued when i am with her bec...         2
# 416800  im truly sorry for the abandoned feeling my fe...         3
# 416801  i do feel my body aching dying crying for slee...         4
# 416802  i can t imagine her having as much of an immed...         5
# 416803       i could never bear feeling a violent thought         0
# 416804  that was what i felt when i was finally accept...         2
# 416805  i take every day as it comes i m just focussin...         1
# 416806      i just suddenly feel that everything was fake         4
# 416807  im feeling more eager than ever to claw back w...         2
# 416808  i give you plenty of attention even when i fee...         4
#
# [416809 rows x 2 columns]

# %%
vocab_size = 15000
embedding_dim = 100
max_length = 100
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 333447

# %%
#This block of code is not used in this Project (try to run without this block to recheck)
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


max_features = 6000
tokenizer = Tokenizer(num_words=max_features, oov_token="<OOV>") #num_word=maximum number of words we want to care about
tokenizer.fit_on_texts(df['text'])
word_index = tokenizer.word_index

sequences = tokenizer.texts_to_sequences(df['text'])

padded = pad_sequences(sequences, padding='post')

#print(padded[0])
#print(padded.shape)

# %%
training_sentences = df.text[0:training_size]
testing_sentences = df.text[training_size:]
training_labels = df.emotions[0:training_size]
testing_labels = df.emotions[training_size:]

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok) #num_word=maximum number of words we want to care about, oov_token deals with the token that is out of vocabulary
tokenizer.fit_on_texts(training_sentences)

word_index = tokenizer.word_index  # this just to see which word is used for which number(index), as the most common word/token will be represented by 1 by tokenizer and so on

training_sequences = tokenizer.texts_to_sequences(training_sentences) # create sequence for the sentences
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %%
# Need this block to get it to work with TensorFlow 2.x
import numpy as np
training_padded = np.array(training_padded)
training_labels = np.array(training_labels)
testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)

# %%
print(np.shape(training_padded))

print(np.shape(training_labels))
# Out:
# (333447, 100)
# (333447,)

# %%
print(np.shape(testing_padded))
# Out:
# (83362, 100)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length), #embedding layer is for vectors direction for multiclass problem in nlp, direction of each word will be learnt epoch by epoch
    tf.keras.layers.GlobalAveragePooling1D(),  # pooling in nlp- adding up the vectors in a particular direction
    
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])

model.compile(optimizer = tf.keras.optimizers.Adam(),
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
num_epochs = 10
history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=2)
# Out:
# Train on 333447 samples, validate on 83362 samples
# Epoch 1/10
# 333447/333447 - 370s - loss: 0.4818 - accuracy: 0.8235 - val_loss: 0.2425 - val_accuracy: 0.8990
# Epoch 2/10
# 333447/333447 - 365s - loss: 0.2050 - accuracy: 0.9089 - val_loss: 0.2065 - val_accuracy: 0.9003
# Epoch 3/10
# 333447/333447 - 371s - loss: 0.1726 - accuracy: 0.9139 - val_loss: 0.1993 - val_accuracy: 0.9005
# Epoch 4/10
# 333447/333447 - 368s - loss: 0.1563 - accuracy: 0.9177 - val_loss: 0.1930 - val_accuracy: 0.8985
# Epoch 5/10
# 333447/333447 - 366s - loss: 0.1470 - accuracy: 0.9206 - val_loss: 0.1962 - val_accuracy: 0.8942
# Epoch 6/10
# 333447/333447 - 366s - loss: 0.1399 - accuracy: 0.9232 - val_loss: 0.2050 - val_accuracy: 0.8945
# Epoch 7/10
# 333447/333447 - 371s - loss: 0.1353 - accuracy: 0.9253 - val_loss: 0.2111 - val_accuracy: 0.8939
# Epoch 8/10
# 333447/333447 - 365s - loss: 0.1310 - accuracy: 0.9270 - val_loss: 0.2297 - val_accuracy: 0.8918
# Epoch 9/10
# 333447/333447 - 369s - loss: 0.1276 - accuracy: 0.9284 - val_loss: 0.2274 - val_accuracy: 0.8897
# Epoch 10/10
# 333447/333447 - 388s - loss: 0.1246 - accuracy: 0.9304 - val_loss: 0.2290 - val_accuracy: 0.8913

# %%
sentence = ["It's a horrible movie waste of time"]
sequences = tokenizer.texts_to_sequences(sentence)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
print(model.predict(padded))
# Out:
# [[1.7880311e-02 1.0132099e-03 6.5801672e-05 3.4366141e-09 9.8103988e-01
#   8.7459921e-07]]

# %%
sentence = ["I feel quite satisfied for this project"]
sequences = tokenizer.texts_to_sequences(sentence)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
print(model.predict(padded))
# Out:
# [[8.3987499e-05 2.3984182e-06 9.9982965e-01 2.6877214e-09 8.3908242e-05
#   2.1253689e-08]]

# %% [markdown]
# ## Using SVM

# %%
from sklearn import svm

clf = svm.SVC()

clf.fit(training_padded, training_labels)

# %%
y_pred=clf.predict(testing_padded)

y_pred

# %%
from sklearn.metrics import accuracy_score

print('SVM Accuracy:',accuracy_score(testing_labels,y_pred))

# %%
#Predict new instances

sentence = ["She is very irritated and annoyed"]
sequences = tokenizer.texts_to_sequences(sentence)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
print(clf.predict(padded))
